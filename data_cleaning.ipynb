# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('era5_database.sqlite')

weather_df = pd.read_sql("SELECT * FROM city_weather", conn)

weather_df.head()
# Out:
#                   time  latitude  longitude  number    step  \
# 0  2021-01-01 06:00:00     35.75     139.75       0  0 days
# 1  2021-01-01 12:00:00     35.75     139.75       0  0 days
# 2  2021-02-01 06:00:00     35.75     139.75       0  0 days
# 3  2021-02-01 12:00:00     35.75     139.75       0  0 days
# 4  2021-03-01 06:00:00     35.75     139.75       0  0 days
#
#    depthBelowLandLayer           valid_time       stl1  surface  slt  \
# 0                  0.0                  NaN        NaN      0.0  NaN
# 1                  0.0  2021-01-01 12:00:00  279.91925      0.0  3.0
# 2                  0.0                  NaN        NaN      0.0  NaN
# 3                  0.0  2021-02-01 12:00:00  281.76420      0.0  3.0
# 4                  0.0                  NaN        NaN      0.0  NaN
#
#            sp        sd       u10       v10        t2m        d2m  \
# 0         NaN       NaN       NaN       NaN        NaN        NaN
# 1  101900.016  0.000084  0.187966 -2.449815  277.37920  272.67170
# 2         NaN       NaN       NaN       NaN        NaN        NaN
# 3  101633.664  0.000000  0.555573 -0.719503  280.37323  273.26367
# 4         NaN       NaN       NaN       NaN        NaN        NaN
#
#              sf         e        ro        tp
# 0  0.000000e+00 -0.000041  0.000015  0.000065
# 1           NaN       NaN       NaN       NaN
# 2  2.980232e-08 -0.000041  0.000011  0.000005
# 3           NaN       NaN       NaN       NaN
# 4  0.000000e+00 -0.000030  0.000009  0.000077

# %%
weather_df = weather_df[['time', 'latitude', 'longitude', 'stl1', 'slt', 'sp', 'sd', 'u10', 'v10', 't2m', 'd2m', 'sf', 'e', 'ro', 'tp']]

# %%
weather_df.dtypes
# Out:
# time             str
# latitude     float64
# longitude    float64
# stl1         float64
# slt          float64
# sp           float64
# sd           float64
# u10          float64
# v10          float64
# t2m          float64
# d2m          float64
# sf           float64
# e            float64
# ro           float64
# tp           float64
# dtype: object

# %%
weather_df['time'] = weather_df['time'].apply(
    lambda x : pd.to_datetime(x[0:10], format='%Y-%m-%d')
)

weather_df.head()
# Out:
#         time  latitude  longitude       stl1  slt          sp        sd  \
# 0 2021-01-01     35.75     139.75        NaN  NaN         NaN       NaN
# 1 2021-01-01     35.75     139.75  279.91925  3.0  101900.016  0.000084
# 2 2021-02-01     35.75     139.75        NaN  NaN         NaN       NaN
# 3 2021-02-01     35.75     139.75  281.76420  3.0  101633.664  0.000000
# 4 2021-03-01     35.75     139.75        NaN  NaN         NaN       NaN
#
#         u10       v10        t2m        d2m            sf         e        ro  \
# 0       NaN       NaN        NaN        NaN  0.000000e+00 -0.000041  0.000015
# 1  0.187966 -2.449815  277.37920  272.67170           NaN       NaN       NaN
# 2       NaN       NaN        NaN        NaN  2.980232e-08 -0.000041  0.000011
# 3  0.555573 -0.719503  280.37323  273.26367           NaN       NaN       NaN
# 4       NaN       NaN        NaN        NaN  0.000000e+00 -0.000030  0.000009
#
#          tp
# 0  0.000065
# 1       NaN
# 2  0.000005
# 3       NaN
# 4  0.000077

# %%
weather_df = weather_df.groupby(['time', 'latitude', 'longitude']).max().reset_index()

weather_df.head()
# Out:
#         time  latitude  longitude       stl1  slt          sp         sd  \
# 0 2021-01-01    -90.00       0.00  232.94269  1.0   68938.016  10.000000
# 1 2021-01-01    -77.75     166.75  267.34894  0.0   96918.016   4.021423
# 2 2021-01-01    -37.75     145.00  292.26690  4.0  100400.016   0.000000
# 3 2021-01-01    -34.50     301.50  298.18097  0.0  101219.016   0.000000
# 4 2021-01-01    -34.00      18.50  295.90167  1.0  100912.016   0.000000
#
#         u10       v10        t2m        d2m        sf             e  \
# 0  0.380349  0.006728  244.23468  240.34161  0.000002  3.189780e-07
# 1 -1.187522 -0.171983  268.30695  263.42755  0.000030 -1.464179e-05
# 2  0.876931  2.148818  290.45734  286.12677  0.000000 -3.708294e-05
# 3 -0.640159 -0.776475  296.24054  289.96466  0.000000 -2.151071e-04
# 4  0.170388  5.962783  294.80304  288.18146  0.000000 -6.900122e-05
#
#              ro        tp
# 0  0.000000e+00  0.000002
# 1  0.000000e+00  0.000030
# 2  1.072884e-06  0.000082
# 3  1.192093e-07  0.000067
# 4  0.000000e+00  0.000003

# %%
weather_df.columns = ['date', 'latitude', 'longitude', 'soil_temperature_level_1', 'soil_type', 'surface_pressure', 'snow_depth', 
    'u_wind_10m', 'v_wind_10m', 'temperature_2m', 'dewpoint_temperature_2m', 'snowfall', 'evaporation', 'runoff', 'total_percipitation']

weather_df.head()
# Out:
#         date  latitude  longitude  soil_temperature_level_1  soil_type  \
# 0 2021-01-01    -90.00       0.00                 232.94269        1.0
# 1 2021-01-01    -77.75     166.75                 267.34894        0.0
# 2 2021-01-01    -37.75     145.00                 292.26690        4.0
# 3 2021-01-01    -34.50     301.50                 298.18097        0.0
# 4 2021-01-01    -34.00      18.50                 295.90167        1.0
#
#    surface_pressure  snow_depth  u_wind_10m  v_wind_10m  temperature_2m  \
# 0         68938.016   10.000000    0.380349    0.006728       244.23468
# 1         96918.016    4.021423   -1.187522   -0.171983       268.30695
# 2        100400.016    0.000000    0.876931    2.148818       290.45734
# 3        101219.016    0.000000   -0.640159   -0.776475       296.24054
# 4        100912.016    0.000000    0.170388    5.962783       294.80304
#
#    dewpoint_temperature_2m  snowfall   evaporation        runoff  \
# 0                240.34161  0.000002  3.189780e-07  0.000000e+00
# 1                263.42755  0.000030 -1.464179e-05  0.000000e+00
# 2                286.12677  0.000000 -3.708294e-05  1.072884e-06
# 3                289.96466  0.000000 -2.151071e-04  1.192093e-07
# 4                288.18146  0.000000 -6.900122e-05  0.000000e+00
#
#    total_percipitation
# 0             0.000002
# 1             0.000030
# 2             0.000082
# 3             0.000067
# 4             0.000003

# %%
city_df = pd.read_csv('cities.csv')

city_df.head()
# Out:
#                location continent  latitude  longitude
# 0          Tokyo, Japan      Asia     35.75     139.75
# 1  Singapore, Singapore      Asia      1.25     103.75
# 2            Dubai, UAE      Asia     25.25      55.25
# 3        Beijing, China      Asia     40.00     116.50
# 4         Mumbai, India      Asia     19.00      73.00

# %%
full_df = weather_df.merge(city_df, how='left', on=['longitude', 'latitude'])

full_df.head()
# Out:
#         date  latitude  longitude  soil_temperature_level_1  soil_type  \
# 0 2021-01-01    -90.00       0.00                 232.94269        1.0
# 1 2021-01-01    -77.75     166.75                 267.34894        0.0
# 2 2021-01-01    -37.75     145.00                 292.26690        4.0
# 3 2021-01-01    -34.50     301.50                 298.18097        0.0
# 4 2021-01-01    -34.00      18.50                 295.90167        1.0
#
#    surface_pressure  snow_depth  u_wind_10m  v_wind_10m  temperature_2m  \
# 0         68938.016   10.000000    0.380349    0.006728       244.23468
# 1         96918.016    4.021423   -1.187522   -0.171983       268.30695
# 2        100400.016    0.000000    0.876931    2.148818       290.45734
# 3        101219.016    0.000000   -0.640159   -0.776475       296.24054
# 4        100912.016    0.000000    0.170388    5.962783       294.80304
#
#    dewpoint_temperature_2m  snowfall   evaporation        runoff  \
# 0                240.34161  0.000002  3.189780e-07  0.000000e+00
# 1                263.42755  0.000030 -1.464179e-05  0.000000e+00
# 2                286.12677  0.000000 -3.708294e-05  1.072884e-06
# 3                289.96466  0.000000 -2.151071e-04  1.192093e-07
# 4                288.18146  0.000000 -6.900122e-05  0.000000e+00
#
#    total_percipitation                     location      continent
# 0             0.000002   Amundsen-Scott, Antarctica     Antarctica
# 1             0.000030  McMurdo Station, Antarctica     Antarctica
# 2             0.000082         Melbourne, Australia        Oceania
# 3             0.000067      Buenos Aires, Argentina  South America
# 4             0.000003      Cape Town, South Africa         Africa

# %%
full_df['soil_type'] = full_df['soil_type'].astype('int64')

full_df = full_df[['location', 'continent', 'date', 'latitude', 'longitude', 'temperature_2m', 'surface_pressure', 'dewpoint_temperature_2m'
    , 'v_wind_10m', 'u_wind_10m', 'evaporation', 'runoff', 'total_percipitation', 'snowfall', 'snow_depth', 'soil_temperature_level_1', 'soil_type']]

full_df.head()
# Out:
#                       location      continent       date  latitude  longitude  \
# 0   Amundsen-Scott, Antarctica     Antarctica 2021-01-01    -90.00       0.00
# 1  McMurdo Station, Antarctica     Antarctica 2021-01-01    -77.75     166.75
# 2         Melbourne, Australia        Oceania 2021-01-01    -37.75     145.00
# 3      Buenos Aires, Argentina  South America 2021-01-01    -34.50     301.50
# 4      Cape Town, South Africa         Africa 2021-01-01    -34.00      18.50
#
#    temperature_2m  surface_pressure  dewpoint_temperature_2m  v_wind_10m  \
# 0       244.23468         68938.016                240.34161    0.006728
# 1       268.30695         96918.016                263.42755   -0.171983
# 2       290.45734        100400.016                286.12677    2.148818
# 3       296.24054        101219.016                289.96466   -0.776475
# 4       294.80304        100912.016                288.18146    5.962783
#
#    u_wind_10m   evaporation        runoff  total_percipitation  snowfall  \
# 0    0.380349  3.189780e-07  0.000000e+00             0.000002  0.000002
# 1   -1.187522 -1.464179e-05  0.000000e+00             0.000030  0.000030
# 2    0.876931 -3.708294e-05  1.072884e-06             0.000082  0.000000
# 3   -0.640159 -2.151071e-04  1.192093e-07             0.000067  0.000000
# 4    0.170388 -6.900122e-05  0.000000e+00             0.000003  0.000000
#
#    snow_depth  soil_temperature_level_1  soil_type
# 0   10.000000                 232.94269          1
# 1    4.021423                 267.34894          0
# 2    0.000000                 292.26690          4
# 3    0.000000                 298.18097          0
# 4    0.000000                 295.90167          1

# %%
full_df.to_csv('city_weather.csv')
